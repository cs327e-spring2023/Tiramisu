# %% [markdown]
# # Q1

# %%
# !mongo open_food --quiet --eval 'db.products.count()'
# Out:
# 309370

# %% [markdown]
# # Q2

# %%
# !mongo open_food --quiet --eval 'db.products.find({"categories": "Snacks, Sweet snacks, Confectioneries, Candies, Chews"}, {"_id":1, "product_name":1}).pretty()'
# Out:
# { "_id" : "0071720007105", "product_name" : "Tootsie Roll" }

# %% [markdown]
# # Q3

# %%
# !mongo open_food --quiet --eval 'db.products.find({"last_modified_t": { $gte:  1601856000}} , {"_id":1, "code":1,"product_name":1}).pretty()'
# Out:
# {
# 	"_id" : "0852909003299",
# 	"product_name" : "Almondmilk",
# 	"code" : "0852909003299"
# }
# {
# 	"_id" : "0840423102055",
# 	"code" : "0840423102055",
# 	"product_name" : "Garlic wine pasta with chicken meatballs with whole wheat rotini, white beans, and greens, cooked in avocado oil, and topped with parmesan and mozzarella, garlic wine pasta with chicken meatballs"
# }

# %% [markdown]
# # Q4

# %%
# !mongo open_food --quiet --eval 'db.products.find({"packaging" : "Plastic"}).count()'
# !mongo open_food --quiet --eval 'db.products.count({"packaging" : "Plastic"})'
# Out:
# 115
# 115

# %% [markdown]
# # Q5

# %%
# !mongo open_food --quiet --eval 'db.products.find({"manufacturing_places" : "Austin, TX", "stores" : "Whole Foods"}, {"_id":1, "code":1, "creator":1, "product_name":1, "brands":1}).pretty()'
# Out:
# {
# 	"_id" : "0099482455859",
# 	"creator" : "usda-ndb-import",
# 	"brands" : "365 Everyday Value,Whole Foods Market  Inc.",
# 	"code" : "0099482455859",
# 	"product_name" : "Whole Wheat Bread"
# }

# %% [markdown]
# # Q6

# %%
# !mongo open_food --quiet --eval 'db.products.find({"$or": [{"brands":"m&m\u0027s", "brands":"mars", "brands":"Mars", "brands":"oreo", "brands":"starburst"}]}, {"_id":1, "product_name":1, "brands":1}).sort({"product_name":1}).limit(5).pretty()'
# Out:
# {
# 	"_id" : "04005108",
# 	"product_name" : "Real fruit juice!",
# 	"brands" : "starburst"
# }

# %% [markdown]
# # Q7 Our data was corrupted and no output was given for the correct frame of reference of values 18<nutriments.carbohydrates_serving<25

# %%
# This is the correct mongo db query but there is no output

# %%
# !mongo open_food --quiet --eval 'db.products.find({"nutriments.carbohydrates_serving": {"$gte":"18", "$lte":"25"}},{"_id":1, "product_name":1, "countries":1, "ingredients.text":1, "ingredients.rank":1, "nutriments.carbohydrates_serving":1}).limit(5).pretty()'

# %%
# this is the query that outputs all

# %%
# !mongo open_food --quiet --eval 'db.products.find({},{"_id":1, "product_name":1, "countries":1, "ingredients.text":1, "ingredients.rank":1, "nutriments.carbohydrates_serving":1}).pretty()'
# Out:
# {
# 	"_id" : "0000000004530",
# 	"countries" : "United States",
# 	"product_name" : "Banana Chips Sweetened (Whole)",
# 	"ingredients" : [
# 		{
# 			"rank" : 1,
# 			"text" : "Bananas"
# 		},
# 		{
# 			"rank" : 2,
# 			"text" : "vegetable oil"
# 		},
# 		{
# 			"rank" : 3,
# 			"text" : "sugar"
# 		},
# 		{
# 			"rank" : 4,
# 			"text" : "natural banana flavor"
# 		},
# 		{
# 			"text" : "coconut oil"
# 		},
# 		{
# 			"text" : "corn oil"
# 		},
# 		{
# 			"text" : "palm oil"
# 		}
# 	],
# 	"nutriments" : {
# 		"carbohydrates_serving" : 18
# 	}
# }
# {
# 	"_id" : "0000000016100",
# 	"product_name" : "Breadshop Honey Gone Nuts Granola",
# 	"countries" : "United States",
# 	"nutriments" : {
# 		"carbohydrates_serving" : 33
# 	},
# 	"ingredients" : [
# 		{
# 			"text" : "Rolled oats",
# 			"rank" : 1
# 		},
# 		{
# 			"rank" : 2,
# 			"text" : "grape"
# 		},
# 		{
# 			"text" : "canola oil",
# 			"rank" : 3
# 		},
# 		{
# 			"text" : "sunflower seeds",
# 			"rank" : 4
# 		},
# 		{
# 			"rank" : 5,
# 			"text" : "almonds"
# 		},
# 		{
# 			"text" : "walnuts oat bran",
# 			"rank" : 6
# 		},
# 		{
# 			"rank" : 7,
# 			"text" : "sesame seeds"
# 		},
# 		{
# 			"rank" : 8,
# 			"text" : "cashews"
# 		},
# 		{
# 			"rank" : 9,
# 			"text" : "natural vitamin e"
# 		}
# 	]
# }
# {
# 	"_id" : "0000000016513",
# 	"countries" : "United States",
# 	"product_name" : "Organic Sunflower Oil",
# 	"nutriments" : {
#
# 	},
# 	"ingredients" : [
# 		{
# 			"rank" : 1,
# 			"text" : "expeller pressed"
# 		},
# 		{
# 			"text" : "refined high oleic sunflower oil",
# 			"rank" : 2
# 		}
# 	]
# }
# {
# 	"_id" : "0000000017497",
# 	"countries" : "United States",
# 	"product_name" : "Organic Spicy Punks",
# 	"nutriments" : {
# 		"carbohydrates_serving" : 5
# 	},
# 	"ingredients" : [
# 		{
# 			"rank" : 1,
# 			"text" : "pumpkin seeds"
# 		},
# 		{
# 			"rank" : 2,
# 			"text" : "tamari"
# 		},
# 		{
# 			"text" : "garlic",
# 			"rank" : 3
# 		},
# 		{
# 			"text" : "cayenne",
# 			"rank" : 4
# 		},
# 		{
# 			"text" : "soybeans"
# 		},
# 		{
# 			"text" : "water"
# 		},
# 		{
# 			"text" : "salt"
# 		}
# 	]
# }
# {
# 	"_id" : "0000000018197",
# 	"product_name" : "Lotus Organic Brown Jasmine Rice",
# 	"countries" : "United States",
# 	"nutriments" : {
# 		"carbohydrates_serving" : 35
# 	},
# 	"ingredients" : [
# 		{
# 			"rank" : 1,
# 			"text" : "brown jasmine rice"
# 		}
# 	]
# }
# {
# 	"_id" : "0000000018319",
# 	"nutriments" : {
# 		"carbohydrates_serving" : 38
# 	},
# 	"countries" : "United States",
# 	"product_name" : "Organic Quinoa Coconut Granola With Mango",
# 	"ingredients" : [
# 		{
# 			"text" : "rolled oats",
# 			"rank" : 1
# 		},
# 		{
# 			"text" : "evaporated cane juice",
# 			"rank" : 2
# 		},
# 		{
# 			"rank" : 3,
# 			"text" : "quinoa flakes"
# 		},
# 		{
# 			"text" : "raisins",
# 			"rank" : 4
# 		},
# 		{
# 			"text" : "canola oil",
# 			"rank" : 5
# 		},
# 		{
# 			"rank" : 6,
# 			"text" : "mango"
# 		},
# 		{
# 			"text" : "oat bran",
# 			"rank" : 7
# 		},
# 		{
# 			"rank" : 8,
# 			"text" : "coconut"
# 		}
# 	]
# }
# {
# 	"_id" : "0000000018418",
# 	"countries" : "United States",
# 	"product_name" : "Wasabi Tamari Almonds",
# 	"ingredients" : [
# 		{
# 			"text" : "Almonds",
# 			"rank" : 1
# 		},
# 		{
# 			"text" : "wasabi spice",
# 			"rank" : 2
# 		},
# 		{
# 			"text" : "tamari shoyu sauce",
# 			"rank" : 3
# 		},
# 		{
# 			"text" : "salt"
# 		},
# 		{
# 			"text" : "rice flour"
# 		},
# 		{
# 			"text" : "evaporated cane juice"
# 		},
# 		{
# 			"text" : "onion powder"
# 		},
# 		{
# 			"text" : "spice extracts"
# 		},
# 		{
# 			"text" : "horseradish"
# 		},
# 		{
# 			"text" : "yeast extract"
# 		},
# 		{
# 			"text" : "parsley"
# 		},
# 		{
# 			"text" : "spice"
# 		},
# 		{
# 			"text" : "garlic powder"
# 		},
# 		{
# 			"text" : "citric acid"
# 		},
# 		{
# 			"text" : "water"
# 		},
# 		{
# 			"text" : "soybeans"
# 		},
# 		{
# 			"text" : "salt"
# 		},
# 		{
# 			"text" : "wheat"
# 		}
# 	],
# 	"nutriments" : {
# 		"carbohydrates_serving" : 7
# 	}
# }
# {
# 	"_id" : "0000000018500",
# 	"ingredients" : [
# 		{
# 			"rank" : 1,
# 			"text" : "Coconut bar"
# 		},
# 		{
# 			"text" : "dark chocolate coating",
# 			"rank" : 2
# 		},
# 		{
# 			"text" : "coconut"
# 		},
# 		{
# 			"text" : "brown rice syrup"
# 		},
# 		{
# 			"text" : "chocolate"
# 		},
# 		{
# 			"text" : "dehydrated cane juice"
# 		},
# 		{
# 			"text" : "cocoa butter"
# 		},
# 		{
# 			"text" : "soy lecithin"
# 		},
# 		{
# 			"text" : "natural vanilla"
# 		},
# 		{
# 			"text" : "as an emulsifier"
# 		}
# 	],
# 	"nutriments" : {
# 		"carbohydrates_serving" : 21
# 	},
# 	"product_name" : "Dark Chocolate Coconut Chews",
# 	"countries" : "United States"
# }
# {
# 	"_id" : "0000000018517",
# 	"ingredients" : [
# 		{
# 			"text" : "semi-sweet chocolate chips",
# 			"rank" : 1
# 		},
# 		{
# 			"rank" : 2,
# 			"text" : "pumpkin seeds"
# 		},
# 		{
# 			"text" : "almonds",
# 			"rank" : 3
# 		},
# 		{
# 			"text" : "cranberries",
# 			"rank" : 4
# 		},
# 		{
# 			"text" : "raisins",
# 			"rank" : 5
# 		},
# 		{
# 			"rank" : 6,
# 			"text" : "coconut"
# 		},
# 		{
# 			"rank" : 7,
# 			"text" : "sunflower seeds"
# 		},
# 		{
# 			"text" : "sugar"
# 		},
# 		{
# 			"text" : "chocolate liquor"
# 		},
# 		{
# 			"text" : "cocoa butter"
# 		},
# 		{
# 			"text" : "soy lecithin"
# 		},
# 		{
# 			"text" : "vanilla"
# 		},
# 		{
# 			"text" : "sweetened with cane juice"
# 		}
# 	],
# 	"nutriments" : {
# 		"carbohydrates_serving" : 13
# 	},
# 	"product_name" : "Seventh Heaven Organic Trail Mix",
# 	"countries" : "United States"
# }
# {
# 	"_id" : "0000000018524",
# 	"product_name" : "Organic Unsweetened Granola, Cinnamon Almond",
# 	"countries" : "United States",
# 	"nutriments" : {
# 		"carbohydrates_serving" : 30
# 	},
# 	"ingredients" : [
# 		{
# 			"rank" : 1,
# 			"text" : "whole rolled oates"
# 		},
# 		{
# 			"rank" : 2,
# 			"text" : "raisins"
# 		},
# 		{
# 			"rank" : 3,
# 			"text" : "canola oil"
# 		},
# 		{
# 			"rank" : 4,
# 			"text" : "flax seed"
# 		},
# 		{
# 			"text" : "corn meal",
# 			"rank" : 5
# 		},
# 		{
# 			"text" : "almonds",
# 			"rank" : 6
# 		},
# 		{
# 			"text" : "coconut",
# 			"rank" : 7
# 		},
# 		{
# 			"text" : "cinnamon",
# 			"rank" : 8
# 		},
# 		{
# 			"rank" : 9,
# 			"text" : "salt"
# 		}
# 	]
# }
# {
# 	"_id" : "0000000018555",
# 	"ingredients" : [
# 		{
# 			"text" : "rolled oats",
# 			"rank" : 1
# 		},
# 		{
# 			"rank" : 2,
# 			"text" : "evaporated cane juice"
# 		},
# 		{
# 			"text" : "canola oil",
# 			"rank" : 3
# 		},
# 		{
# 			"text" : "raisins",
# 			"rank" : 4
# 		},
# 		{
# 			"text" : "apples",
# 			"rank" : 5
# 		},
# 		{
# 			"text" : "almonds",
# 			"rank" : 6
# 		},
# 		{
# 			"rank" : 7,
# 			"text" : "oat bran"
# 		},
# 		{
# 			"text" : "blueberries",
# 			"rank" : 8
# 		},
# 		{
# 			"rank" : 9,
# 			"text" : "sunflower seeds"
# 		}
# 	],
# 	"nutriments" : {
# 		"carbohydrates_serving" : 39
# 	},
# 	"countries" : "United States",
# 	"product_name" : "Organic Blueberry Almond Granola"
# }
# {
# 	"_id" : "0000000018562",
# 	"product_name" : "Sweeteners, Demerara Turbinado Sugar",
# 	"countries" : "United States",
# 	"ingredients" : [
# 		{
# 			"rank" : 1,
# 			"text" : "Raw cane demerara sugar"
# 		}
# 	],
# 	"nutriments" : {
# 		"carbohydrates_serving" : 4
# 	}
# }
# {
# 	"_id" : "0000000018579",
# 	"product_name" : "Aunt Maple's Crunchy Granola",
# 	"countries" : "United States",
# 	"ingredients" : [
# 		{
# 			"text" : "rolled oats",
# 			"rank" : 1
# 		},
# 		{
# 			"rank" : 2,
# 			"text" : "flame raisins"
# 		},
# 		{
# 			"text" : "coconut chips",
# 			"rank" : 3
# 		},
# 		{
# 			"rank" : 4,
# 			"text" : "maple syrup"
# 		},
# 		{
# 			"rank" : 5,
# 			"text" : "sunflower oil"
# 		},
# 		{
# 			"rank" : 6,
# 			"text" : "walnuts"
# 		},
# 		{
# 			"text" : "almonds",
# 			"rank" : 7
# 		},
# 		{
# 			"text" : "wheat germ",
# 			"rank" : 8
# 		},
# 		{
# 			"text" : "honey",
# 			"rank" : 9
# 		},
# 		{
# 			"rank" : 10,
# 			"text" : "crunchy almond butter"
# 		},
# 		{
# 			"text" : "hazelnuts",
# 			"rank" : 11
# 		},
# 		{
# 			"text" : "almonds",
# 			"rank" : 12
# 		},
# 		{
# 			"rank" : 13,
# 			"text" : "cinnamon"
# 		},
# 		{
# 			"text" : "vanilla extract",
# 			"rank" : 14
# 		},
# 		{
# 			"text" : "dry roasted almonds"
# 		}
# 	],
# 	"nutriments" : {
# 		"carbohydrates_serving" : 31
# 	}
# }
# {
# 	"_id" : "0000000018630",
# 	"product_name" : "Organic Coconut Chips",
# 	"countries" : "United States",
# 	"nutriments" : {
# 		"carbohydrates_serving" : 24
# 	},
# 	"ingredients" : [
# 		{
# 			"text" : "coconut",
# 			"rank" : 1
# 		}
# 	]
# }
# {
# 	"_id" : "0000000018869",
# 	"ingredients" : [
# 		{
# 			"text" : "rolled oats",
# 			"rank" : 1
# 		},
# 		{
# 			"rank" : 2,
# 			"text" : "brown rice syrup"
# 		},
# 		{
# 			"text" : "flame raisins",
# 			"rank" : 3
# 		},
# 		{
# 			"rank" : 4,
# 			"text" : "sunflower oil"
# 		},
# 		{
# 			"rank" : 5,
# 			"text" : "wheat germ"
# 		},
# 		{
# 			"rank" : 6,
# 			"text" : "unsulphured blackstrap molasses"
# 		},
# 		{
# 			"rank" : 7,
# 			"text" : "maple syrup"
# 		},
# 		{
# 			"text" : "honey",
# 			"rank" : 8
# 		},
# 		{
# 			"rank" : 9,
# 			"text" : "almond butter"
# 		},
# 		{
# 			"rank" : 10,
# 			"text" : "cashews"
# 		},
# 		{
# 			"text" : "almonds",
# 			"rank" : 11
# 		},
# 		{
# 			"text" : "spices",
# 			"rank" : 12
# 		}
# 	],
# 	"nutriments" : {
# 		"carbohydrates_serving" : 36
# 	},
# 	"countries" : "United States",
# 	"product_name" : "Aunt Ginger's Snappy Granola"
# }
# {
# 	"_id" : "0000000030540",
# 	"nutriments" : {
# 		"carbohydrates_serving" : 25
# 	},
# 	"countries" : "United States",
# 	"product_name" : "Organic Garbanzo Beans",
# 	"ingredients" : [
# 		{
# 			"rank" : 1,
# 			"text" : "garbanzo beans"
# 		}
# 	]
# }
# {
# 	"_id" : "0000000030595",
# 	"product_name" : "Organic Grey-Green Lentils",
# 	"countries" : "United States",
# 	"nutriments" : {
# 		"carbohydrates_serving" : 30
# 	},
# 	"ingredients" : [
# 		{
# 			"rank" : 1,
# 			"text" : "grey-green lentils"
# 		}
# 	]
# }
# {
# 	"_id" : "0000000030717",
# 	"ingredients" : [
# 		{
# 			"rank" : 1,
# 			"text" : "baby lima beans"
# 		}
# 	],
# 	"nutriments" : {
# 		"carbohydrates_serving" : 28
# 	},
# 	"product_name" : "Organic Baby Lima Beans",
# 	"countries" : "United States"
# }
# {
# 	"_id" : "0000000030724",
# 	"nutriments" : {
# 		"carbohydrates_serving" : 25
# 	},
# 	"product_name" : "Organic Dark Red Kidney Bean",
# 	"countries" : "United States",
# 	"ingredients" : [
# 		{
# 			"text" : "dark red kidney bean",
# 			"rank" : 1
# 		}
# 	]
# }
# {
# 	"_id" : "0000000031172",
# 	"ingredients" : [
# 		{
# 			"rank" : 1,
# 			"text" : "Whole rolled oats"
# 		},
# 		{
# 			"rank" : 2,
# 			"text" : "milled cane sugar"
# 		},
# 		{
# 			"text" : "vegetable oil",
# 			"rank" : 3
# 		},
# 		{
# 			"text" : "molasses",
# 			"rank" : 4
# 		},
# 		{
# 			"rank" : 5,
# 			"text" : "maple syrup"
# 		},
# 		{
# 			"text" : "almonds",
# 			"rank" : 6
# 		},
# 		{
# 			"rank" : 7,
# 			"text" : "honey"
# 		},
# 		{
# 			"text" : "natural flavor",
# 			"rank" : 8
# 		},
# 		{
# 			"text" : "salt",
# 			"rank" : 9
# 		},
# 		{
# 			"rank" : 10,
# 			"text" : "cardamom seed"
# 		},
# 		{
# 			"rank" : 11,
# 			"text" : "fennel seed"
# 		},
# 		{
# 			"rank" : 12,
# 			"text" : "fenugreek seed"
# 		},
# 		{
# 			"text" : "nutmeg",
# 			"rank" : 13
# 		},
# 		{
# 			"text" : "canola"
# 		},
# 		{
# 			"text" : "sunflower oil"
# 		}
# 	],
# 	"nutriments" : {
# 		"carbohydrates_serving" : 37
# 	},
# 	"product_name" : "Maple Almond Granola",
# 	"countries" : "United States"
# }
# Type "it" for more

# %%
# !mongo open_food --quiet --eval 'db.products.insertOne({ "_id" : 0000005789, "product_name" : "Tiramisu", "brands" : "you mom", "creator" : "My", "code" :  0000005789,  })'
# Out:
# { "acknowledged" : true, "insertedId" : 5789 }

# %%
# !mongo open_food --quiet --eval 'db.products.find({ "_id" : 0000005789},{})'
# Out:
# { "_id" : 5789, "product_name" : "Tiramisu", "brands" : "you mom", "creator" : "My", "code" : 5789 }

# %%
# !mongo open_food --quiet --eval 'db.products.updateOne( { "creator" : "My" }, {"$set": {"brands": "my mom"}})'
# Out:
# { "acknowledged" : true, "matchedCount" : 1, "modifiedCount" : 1 }

# %%
# !mongo open_food --quiet --eval 'db.products.find({ "creator" : "My"},{})'
# Out:
# { "_id" : 5789, "product_name" : "Tiramisu", "brands" : "my mom", "creator" : "My", "code" : 5789 }

# %%
# !mongo open_food --quiet --eval 'db.products.deleteOne( { "creator" : "My"} )'
# Out:
# { "acknowledged" : true, "deletedCount" : 1 }

# %%
# !mongo open_food --quiet --eval 'db.products.find({ "creator" : "My"},{})'
